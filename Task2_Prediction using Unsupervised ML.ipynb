# %% [markdown]
# #GRIPMAR21 #TSF #DATASCIENCE
#
# ### GONE YOGANANDA SRIHARI PRASAD,
#
# #### Data Science & Business Analytics intern @ GRIP | THE SPARKS FOUNDATION 2021

# %% [markdown]
# ## Prediction using Unsupervised ML

# %% [markdown]
# ### From the given ‘Iris’ dataset, predict the optimum number of clusters and represent it visually.

# %% [markdown]
# Dataset : https://bit.ly/3kXTdox

# %% [markdown]
# #### Importing required import statements

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets

# %% [markdown]
# #### Importing Data

# %%
iris = datasets.load_iris()
iris_df = pd.DataFrame(iris.data, columns = iris.feature_names)
# Out:
# Data imported successfully

# %%
iris = datasets.load_iris()
iris_df = pd.DataFrame(iris.data, columns = iris.feature_names)
print("Data imported successfully")
# Out:
# Data imported successfully

# %% [markdown]
# #### Printing First 5 rows

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         149.000000        149.000000         149.000000
# mean            5.843624          3.059732           3.748993
# std             0.830851          0.436342           1.767791
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.300000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        149.000000
# mean           1.194631
# std            0.762622
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
iris_df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000024665BA0670>,
# ...
#       dtype=object)

# %%
sns.pairplot(iris_df,size=3)
plt.show()
# Out:
# D:\PythonAnaconda\AnacondaInstallation\lib\site-packages\seaborn\axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
x = iris_df.iloc[:, [0, 1, 2, 3]].values

from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', 
                    max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
    

plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# #### We choose 3 clusters from this one

# %% [markdown]
# #### Applying kmeans to the dataset / Creating the kmeans classifier

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++',max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(x)

# %% [markdown]
# #### Visualising the clusters - On the first two columns

# %%
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1],s = 100, c = 'green', label = 'Iris-virginica')

# Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'yellow', label = 'Centroids')

plt.legend()

# %% [markdown]
# #### Thus,  the conclusion of k-means is done

# %% [markdown]
# #### This project was done by Gone Yogananda Srihari Prasad, that is me, under GRIP Program 2021

# %% [markdown]
# #### Thank you
